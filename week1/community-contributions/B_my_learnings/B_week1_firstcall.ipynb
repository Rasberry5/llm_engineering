# %% [markdown]
# This is my first commercial call to OpenAI!
# My AI Learning journey starts now and I'm very excited.

# %%
#Set up the environment

import os
from dotenv import load_dotenv
from IPython.display import Markdown, display
from openai import OpenAI
openai = OpenAI()

# %%
# Load environment variables in a file called .env

load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

# Check the key

if not api_key:
    print("No API key was found - please head over to the troubleshooting notebook in this folder to identify & fix!")
elif not api_key.startswith("sk-proj-"):
    print("An API key was found, but it doesn't start sk-proj-; please check you're using the right key - see troubleshooting notebook")
elif api_key.strip() != api_key:
    print("An API key was found, but it looks like it might have space or tab characters at the start or end - please remove them - see troubleshooting notebook")
else:
    print("API key found and looks good so far!")
# Out:
# API key found and looks good so far!

# %%
# Step 1: Create your prompts

system_prompt = """You are a technology evangelist and always thinking about for what's the new breakthrough technology that will change our world"""
user_prompt = """What are 2 technologies that will transform the way we live, work, play in the next 5 to 10 years?
"""

# Step 2: Make the messages list

messages = [{"role": "system", "content": system_prompt}, {"role": "user", "content": user_prompt}] 

# Step 3: Call OpenAI

response = openai.chat.completions.create(
    model="gpt-4o-mini",
    messages=messages
)

# Step 4: print the result
print(response.choices[0].message.content)
# Out:
# In the next 5 to 10 years, two key technologies are poised to transform our lives in significant ways: **Artificial Intelligence (AI) advancements** and **Extended Reality (XR)**, which encompasses virtual reality (VR), augmented reality (AR), and mixed reality (MR).
#
# ### 1. Artificial Intelligence (AI) Advancements
# AI is on a trajectory to become more sophisticated and integrated into various aspects of daily life. Here’s how it will transform our world:
#
# - **Personalized Living and Working**: AI's ability to analyze vast datasets and recognize patterns will lead to highly personalized experiences in various sectors. From tailored healthcare regimens and education methods to customized work environments and productivity tools, AI will enhance our lives by predicting and catering to our individual needs.
#
# - **Automation of Tasks**: As AI continues to advance, we will see the automation of not just manual labor but also high-skill jobs. This includes everything from advanced data analysis to creative tasks, thereby freeing humans to focus on strategic and interpersonal roles that require emotional intelligence and creativity.
#
# - **Improved Decision-Making**: With AI tools, businesses will be able to gain insights from complex data sets, leading to better decision-making processes. This can significantly impact industries like finance, healthcare, and logistics, transforming efficiency and outcomes.
#
# ### 2. Extended Reality (XR)
# Extended Reality, which includes VR, AR, and MR, is set to redefine entertainment, education, and even social interaction.
#
# - **Immersive Education and Training**: XR technologies can create immersive environments for learners and trainees. This enables hands-on experiences in fields like medicine, engineering, and art, making education more engaging and effective. Training simulations can provide safe spaces for practicing critical skills, improving retention and application in real-world scenarios.
#
# - **Social and Collaborative Spaces**: XR will revolutionize social interactions and collaborative work environments. Virtual offices will allow teams to work together seamlessly, regardless of physical location, making remote collaboration feel more natural and effective. This will lead to new norms in how we communicate and work together, blending real-world connections with virtual experiences.
#
# - **Entertainment and Gaming Evolution**: In the gaming industry, XR will create hyper-realistic experiences that blur the lines between the virtual and physical world, enhancing the way we play and interact with games. Beyond gaming, XR will also find applications in virtual events, concerts, and interactive storytelling, providing unique experiences that reshape entertainment.
#
# Together, these technologies are not only enhancing our current practices but are also reimagining how we interact with the world around us, potentially leading to new forms of productivity, creativity, and social engagement.

# %%
display(Markdown(response.choices[0].message.content))
# Out:
# In the next 5 to 10 years, two key technologies are poised to transform our lives in significant ways: **Artificial Intelligence (AI) advancements** and **Extended Reality (XR)**, which encompasses virtual reality (VR), augmented reality (AR), and mixed reality (MR).
#
# ### 1. Artificial Intelligence (AI) Advancements
# AI is on a trajectory to become more sophisticated and integrated into various aspects of daily life. Here’s how it will transform our world:
#
# - **Personalized Living and Working**: AI's ability to analyze vast datasets and recognize patterns will lead to highly personalized experiences in various sectors. From tailored healthcare regimens and education methods to customized work environments and productivity tools, AI will enhance our lives by predicting and catering to our individual needs.
#
# - **Automation of Tasks**: As AI continues to advance, we will see the automation of not just manual labor but also high-skill jobs. This includes everything from advanced data analysis to creative tasks, thereby freeing humans to focus on strategic and interpersonal roles that require emotional intelligence and creativity.
#
# - **Improved Decision-Making**: With AI tools, businesses will be able to gain insights from complex data sets, leading to better decision-making processes. This can significantly impact industries like finance, healthcare, and logistics, transforming efficiency and outcomes.
#
# ### 2. Extended Reality (XR)
# Extended Reality, which includes VR, AR, and MR, is set to redefine entertainment, education, and even social interaction.
#
# - **Immersive Education and Training**: XR technologies can create immersive environments for learners and trainees. This enables hands-on experiences in fields like medicine, engineering, and art, making education more engaging and effective. Training simulations can provide safe spaces for practicing critical skills, improving retention and application in real-world scenarios.
#
# - **Social and Collaborative Spaces**: XR will revolutionize social interactions and collaborative work environments. Virtual offices will allow teams to work together seamlessly, regardless of physical location, making remote collaboration feel more natural and effective. This will lead to new norms in how we communicate and work together, blending real-world connections with virtual experiences.
#
# - **Entertainment and Gaming Evolution**: In the gaming industry, XR will create hyper-realistic experiences that blur the lines between the virtual and physical world, enhancing the way we play and interact with games. Beyond gaming, XR will also find applications in virtual events, concerts, and interactive storytelling, providing unique experiences that reshape entertainment.
#
# Together, these technologies are not only enhancing our current practices but are also reimagining how we interact with the world around us, potentially leading to new forms of productivity, creativity, and social engagement.
